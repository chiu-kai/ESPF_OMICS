# %% [markdown]
# #### Find common drug_names and export PDAC drug MACCS166bits file
#
# PDAC_MACCS.csv

# %%
import pandas as pd
PDAC_df = pd.read_csv("./PDAC_unique_642_Quadruplet.csv", sep=',', index_col=0)

# %%
PDAC_df
# Out:
#              Sex  ECOG   BirthDay   Dead Last_Follow-up_Date  \
# Patient_ID
# 23          Male     1  1950/4/17  False            2023/8/1
# 23          Male     1  1950/4/17  False            2023/8/1
# 23          Male     1  1950/4/17  False            2023/8/1
# 23          Male     1  1950/4/17  False            2023/8/1
# 23          Male     1  1950/4/17  False            2023/8/1
# ...          ...   ...        ...    ...                 ...
# 508         Male     1  1957/1/10  False            2024/1/9
# 508         Male     1  1957/1/10  False            2024/1/9
# 508         Male     1  1957/1/10  False            2024/1/9
# 508         Male     1  1957/1/10  False            2024/1/9
# 508         Male     1  1957/1/10  False            2024/1/9
#
#            Imaging_Diagnosis_Date Pathological_Diagnosis_Date  \
# Patient_ID
# 23                       2020/8/6                   2020/8/17
# 23                       2020/8/6                   2020/8/17
# ...
