# %%
import torch
device = (torch.device('cuda') if torch.cuda.is_available()
            else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %%
# information
filename     = "ESPF_PretrainAE_exp"

# %%
import numpy as np
import time
import copy
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.utils.data import DataLoader, random_split
import pandas as pd

class AE_dense_3layers(nn.Module):
    def __init__(self, input_dim, mut_encode_dim, activation_func):
        super(AE_dense_3layers, self).__init__()##__init__初始化父類別的屬性和方法
        print('input_dim = ', input_dim)
        print('first_layer_dim = ', mut_encode_dim[0])
        print('second_layer_dim = ', mut_encode_dim[1])
        print('third_layer_dim = ', mut_encode_dim[2])
        # nn.Module 自己將batch 裡的samples 拆開一個一個送入self.encoder nn.Sequential
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, mut_encode_dim[0]),
            activation_func,
            nn.Linear(mut_encode_dim[0], mut_encode_dim[1]),
            activation_func,
            nn.Linear(mut_encode_dim[1], mut_encode_dim[2]),
            activation_func
        )
        self.decoder = nn.Sequential(
            nn.Linear(mut_encode_dim[2], mut_encode_dim[1]),
            activation_func,
            nn.Linear(mut_encode_dim[1], mut_encode_dim[0]),
            activation_func,
            nn.Linear(mut_encode_dim[0], input_dim),
            activation_func
        )
        # Initialize weights using He uniform initialization
        for layer in [self.encoder[0], self.encoder[2], self.encoder[4], self.decoder[0], self.decoder[2], self.decoder[4]]:
            if isinstance(layer, nn.Linear):
                init.kaiming_uniform_(layer.weight, nonlinearity='relu')

    def forward(self, x):#加self才能呼叫self裡其他的屬性和method
        x_encoded = self.encoder(x)
        x_decoded = self.decoder(x_encoded)
        return x_decoded

# %% [markdown]
# ## def warmup_lr_scheduler

# %%
# lr_scheduler
def warmup_lr_scheduler(optimizer, warmup_iters,Decrease_percent):
    def f(epoch):
        if epoch >= warmup_iters:
          return Decrease_percent ** (epoch-warmup_iters+1)
        return 1
    return torch.optim.lr_scheduler.LambdaLR(optimizer, f)

# %%
import random

# Function to set the seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Set the seed
seed = 42
set_seed(seed)

# %%
# load TCGA mutation data, substitute here with other genomics
data_mut_tcga= pd.read_csv("../data/TCGA/TCGA_exp_matchCCLEgenes_8238samples_4692genes.txt", sep='\t', index_col=0)

print("\n\nDatasets successfully loaded.")
# Out:
# Datasets successfully loaded.

# %%
data_mut_tcga.shape
# Out:
# (8238, 4692)

# %%
# #exchange the row and column to match the format of doctor chiu's data (row is gene ;column is cancer)
# data_mut_tcga=data_mut_tcga.transpose()
# data_mut_tcga.shape

# %% [markdown]
# #### 也許應該要分train validation set，這樣才能更學到真正重要的特徵，而不是背答案

# %%
if __name__ == '__main__':#被別人呼叫的時候不會執行main以下的程式，只會執行

    input_dim = data_mut_tcga.shape[1]# (8238sample[0], 2649gene[1])
    mut_encode_dim =[1250,250,50]
    batch_size = 64
    epoch_size = 300 #100
    activation_function = nn.ReLU()
    model_save_name = "tcga_exp_%d_%d_%d" % (mut_encode_dim[0], mut_encode_dim[1], mut_encode_dim[2])
    learning_rate=0.001
    warmup_iters = 100
    patience = 50
    Decrease_percent = 1
    seed=42
    

    torch.manual_seed(seed)
    np.random.seed(seed)
    train_size = int(0.8 * len(data_mut_tcga))
    test_size = len(data_mut_tcga) - train_size
    # Split data into training and testing sets
    train_data, test_data = random_split(data_mut_tcga.values, [train_size, test_size])

    # Create DataLoaders for training and testing
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

    t = time.time()
    torch.manual_seed(seed)
    model = AE_dense_3layers(input_dim=input_dim, mut_encode_dim=mut_encode_dim, activation_func=activation_function).to(device=device)
    criterion = nn.MSELoss()
    
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    if warmup_iters is not None:
        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters,Decrease_percent)
    
    # Training with early stopping (assuming you've defined the EarlyStopping logic)
    
    best_val_loss = float('inf')
    best_weight=None
    counter = 0
    train_epoch_loss_list = []#  for train every epoch loss plot
    test_epoch_loss_list=[]#  for validation every epoch loss plot
    torch.manual_seed(seed)

    for epoch in range(epoch_size):
        model.train()
        model.requires_grad = True
        total_train_loss = 0.0
        for batch_idx,inputs in enumerate(train_loader):
            optimizer.zero_grad()
            inputs =inputs.float().to(device=device) # change torch.Tensor int64 to float32
            outputs = model(inputs)
            loss = criterion(outputs, inputs)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item() # sum every batch's loss to compute average loss of every batch for one epoch
            #print(f'Epoch {epoch + 1}/{epoch_size} - Batch {batch_idx+1}/{len(dataloader_mut_tcga)} - Loss: {loss.item():.4f}')#batch loss()
        # Calculate and print the average loss of batch for the epoch
        average_loss = total_train_loss / len(train_loader) # 一個 epoch 的 loss 是 batch 的 average loss
        train_epoch_loss_list.append(average_loss)# for loss plot'
        print(f'Epoch {epoch + 1}/{epoch_size} - Train Loss: {average_loss:.8f}')
        
        model.eval()
        model.requires_grad = False
        total_test_loss = 0.0
        
        with torch.no_grad():
            for batch_idx,inputs in enumerate(test_loader):
                inputs =inputs.float().to(device=device) # change torch.Tensor int64 to float32
                outputs = model(inputs)
                test_loss = criterion(outputs, inputs)
                total_test_loss += test_loss.item() 
        test_average_loss = total_test_loss / len(test_loader)
        test_epoch_loss_list.append(test_average_loss)# for loss plot'
        print(f'Epoch {epoch + 1}/{epoch_size} - Test Loss: {test_average_loss:.8f}')

        if warmup_iters:
            print("lr of epoch", epoch + 1, "=>", lr_scheduler.get_lr()) 
            lr_scheduler.step()
        
        if test_average_loss < best_val_loss:
            best_val_loss = test_average_loss
            best_weight = copy.deepcopy(model.state_dict())
            best_epoch = epoch+1
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping after {patience} epochs of no improvement.')
                break
                
    encoder_best_weight = {key: value for key, value in best_weight.items() if key.startswith('encoder')} # only store the encoder part without decoder part
    torch.save(encoder_best_weight, f'/root/DeepTTA/results/Encoder_{model_save_name}_best_loss_{best_val_loss:.8}.pt')
    
    print('batch_size:',batch_size," ",'activation_function:',activation_function," ",
          'learning_rate:',learning_rate," ",'warmup_iters:',warmup_iters)
    print("best Epoch : ",best_epoch," ," ,"best_val_loss : ",best_val_loss)
    print('\nAutoencoder training completed in %.1f mins.\n' % ((time.time() - t) / 60))
# Out:
# input_dim =  4692
# first_layer_dim =  1250
# second_layer_dim =  250
# third_layer_dim =  50
# Epoch 1/300 - Train Loss: 7.35857383
# Epoch 1/300 - Test Loss: 6.20057906
# lr of epoch 1 => [0.001]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:265: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Epoch 2/300 - Train Loss: 6.21850202
# Epoch 2/300 - Test Loss: 6.19040442
# lr of epoch 2 => [0.001]
# Epoch 3/300 - Train Loss: 6.20854074
# Epoch 3/300 - Test Loss: 6.17709393
# lr of epoch 3 => [0.001]
# Epoch 4/300 - Train Loss: 6.18177485
# Epoch 4/300 - Test Loss: 6.13581241
# lr of epoch 4 => [0.001]
# Epoch 5/300 - Train Loss: 6.13543578
# Epoch 5/300 - Test Loss: 6.06928242
# lr of epoch 5 => [0.001]
# Epoch 6/300 - Train Loss: 6.09145526
# Epoch 6/300 - Test Loss: 6.05361550
# lr of epoch 6 => [0.001]
# Epoch 7/300 - Train Loss: 6.08580513
# Epoch 7/300 - Test Loss: 5.97662698
# lr of epoch 7 => [0.001]
# Epoch 8/300 - Train Loss: 5.99002977
# Epoch 8/300 - Test Loss: 5.95876360
# lr of epoch 8 => [0.001]
# Epoch 9/300 - Train Loss: 5.97754955
# Epoch 9/300 - Test Loss: 5.95170346
# lr of epoch 9 => [0.001]
# Epoch 10/300 - Train Loss: 5.94708745
# Epoch 10/300 - Test Loss: 5.88389301
# lr of epoch 10 => [0.001]
# Epoch 11/300 - Train Loss: 5.87754017
# Epoch 11/300 - Test Loss: 5.79996641
# lr of epoch 11 => [0.001]
# Epoch 12/300 - Train Loss: 5.81000068
# Epoch 12/300 - Test Loss: 5.76917201
# lr of epoch 12 => [0.001]
# Epoch 13/300 - Train Loss: 5.74027576
# Epoch 13/300 - Test Loss: 5.81767755
# lr of epoch 13 => [0.001]
# Epoch 14/300 - Train Loss: 5.69135049
# Epoch 14/300 - Test Loss: 5.65743949
# lr of epoch 14 => [0.001]
# Epoch 15/300 - Train Loss: 5.67114202
# Epoch 15/300 - Test Loss: 5.62427759
# lr of epoch 15 => [0.001]
# Epoch 16/300 - Train Loss: 5.63160199
# Epoch 16/300 - Test Loss: 5.59103137
# lr of epoch 16 => [0.001]
# Epoch 17/300 - Train Loss: 5.59932765
# Epoch 17/300 - Test Loss: 5.56186216
# lr of epoch 17 => [0.001]
# Epoch 18/300 - Train Loss: 5.55029448
# Epoch 18/300 - Test Loss: 5.50072864
# lr of epoch 18 => [0.001]
# Epoch 19/300 - Train Loss: 5.50680106
# Epoch 19/300 - Test Loss: 5.42828024
# lr of epoch 19 => [0.001]
# Epoch 20/300 - Train Loss: 5.29699259
# Epoch 20/300 - Test Loss: 5.04455651
# lr of epoch 20 => [0.001]
# Epoch 21/300 - Train Loss: 5.05201037
# Epoch 21/300 - Test Loss: 5.02857925
# lr of epoch 21 => [0.001]
# Epoch 22/300 - Train Loss: 5.03355370
# Epoch 22/300 - Test Loss: 5.01188854
# lr of epoch 22 => [0.001]
# Epoch 23/300 - Train Loss: 5.01100186
# Epoch 23/300 - Test Loss: 4.97062443
# lr of epoch 23 => [0.001]
# Epoch 24/300 - Train Loss: 4.99431456
# Epoch 24/300 - Test Loss: 4.86108983
# lr of epoch 24 => [0.001]
# Epoch 25/300 - Train Loss: 4.85994302
# Epoch 25/300 - Test Loss: 4.82619652
# lr of epoch 25 => [0.001]
# Epoch 26/300 - Train Loss: 4.82616028
# Epoch 26/300 - Test Loss: 4.78096947
# lr of epoch 26 => [0.001]
# Epoch 27/300 - Train Loss: 4.79013431
# Epoch 27/300 - Test Loss: 4.77781745
# lr of epoch 27 => [0.001]
# Epoch 28/300 - Train Loss: 4.75390099
# Epoch 28/300 - Test Loss: 4.72472846
# lr of epoch 28 => [0.001]
# Epoch 29/300 - Train Loss: 4.72412977
# Epoch 29/300 - Test Loss: 4.66338675
# lr of epoch 29 => [0.001]
# Epoch 30/300 - Train Loss: 4.61647091
# Epoch 30/300 - Test Loss: 4.51094481
# lr of epoch 30 => [0.001]
# Epoch 31/300 - Train Loss: 4.27792173
# Epoch 31/300 - Test Loss: 3.99684882
# lr of epoch 31 => [0.001]
# Epoch 32/300 - Train Loss: 6.54441556
# Epoch 32/300 - Test Loss: 3.86916591
# lr of epoch 32 => [0.001]
# Epoch 33/300 - Train Loss: 3.81456300
# Epoch 33/300 - Test Loss: 3.80726761
# lr of epoch 33 => [0.001]
# Epoch 34/300 - Train Loss: 3.80234177
# Epoch 34/300 - Test Loss: 3.79716845
# lr of epoch 34 => [0.001]
# Epoch 35/300 - Train Loss: 3.79896601
# Epoch 35/300 - Test Loss: 3.79539719
# lr of epoch 35 => [0.001]
# Epoch 36/300 - Train Loss: 3.79849641
# Epoch 36/300 - Test Loss: 3.79598094
# lr of epoch 36 => [0.001]
# Epoch 37/300 - Train Loss: 3.79819935
# Epoch 37/300 - Test Loss: 3.79575829
# lr of epoch 37 => [0.001]
# Epoch 38/300 - Train Loss: 3.79687529
# Epoch 38/300 - Test Loss: 3.79350385
# lr of epoch 38 => [0.001]
# Epoch 39/300 - Train Loss: 3.79662206
# Epoch 39/300 - Test Loss: 3.79433911
# lr of epoch 39 => [0.001]
# Epoch 40/300 - Train Loss: 3.79616025
# Epoch 40/300 - Test Loss: 3.79335983
# lr of epoch 40 => [0.001]
# Epoch 41/300 - Train Loss: 3.79572847
# Epoch 41/300 - Test Loss: 3.79389756
# lr of epoch 41 => [0.001]
# Epoch 42/300 - Train Loss: 3.79493175
# Epoch 42/300 - Test Loss: 3.79199446
# lr of epoch 42 => [0.001]
# Epoch 43/300 - Train Loss: 3.79537373
# Epoch 43/300 - Test Loss: 3.79355676
# lr of epoch 43 => [0.001]
# Epoch 44/300 - Train Loss: 3.79495196
# Epoch 44/300 - Test Loss: 3.79340086
# lr of epoch 44 => [0.001]
# Epoch 45/300 - Train Loss: 3.79623641
# Epoch 45/300 - Test Loss: 3.79094373
# lr of epoch 45 => [0.001]
# Epoch 46/300 - Train Loss: 3.79415707
# Epoch 46/300 - Test Loss: 3.79056306
# lr of epoch 46 => [0.001]
# Epoch 47/300 - Train Loss: 3.79419067
# Epoch 47/300 - Test Loss: 3.79094366
# lr of epoch 47 => [0.001]
# Epoch 48/300 - Train Loss: 3.79563937
# Epoch 48/300 - Test Loss: 3.78957439
# lr of epoch 48 => [0.001]
# Epoch 49/300 - Train Loss: 3.79303714
# Epoch 49/300 - Test Loss: 3.79007728
# lr of epoch 49 => [0.001]
# Epoch 50/300 - Train Loss: 3.79203428
# Epoch 50/300 - Test Loss: 3.78748862
# lr of epoch 50 => [0.001]
# Epoch 51/300 - Train Loss: 3.79201056
# Epoch 51/300 - Test Loss: 3.78581004
# lr of epoch 51 => [0.001]
# Epoch 52/300 - Train Loss: 3.79299325
# Epoch 52/300 - Test Loss: 3.78659448
# lr of epoch 52 => [0.001]
# Epoch 53/300 - Train Loss: 3.78854235
# Epoch 53/300 - Test Loss: 3.78286850
# lr of epoch 53 => [0.001]
# Epoch 54/300 - Train Loss: 3.78931047
# Epoch 54/300 - Test Loss: 3.78287712
# lr of epoch 54 => [0.001]
# Epoch 55/300 - Train Loss: 3.78882101
# Epoch 55/300 - Test Loss: 3.78588320
# lr of epoch 55 => [0.001]
# Epoch 56/300 - Train Loss: 3.78758621
# Epoch 56/300 - Test Loss: 3.78152899
# lr of epoch 56 => [0.001]
# Epoch 57/300 - Train Loss: 3.78991598
# Epoch 57/300 - Test Loss: 3.78161790
# lr of epoch 57 => [0.001]
# Epoch 58/300 - Train Loss: 3.78401585
# Epoch 58/300 - Test Loss: 3.77869374
# lr of epoch 58 => [0.001]
# Epoch 59/300 - Train Loss: 3.78748903
# Epoch 59/300 - Test Loss: 3.78251224
# lr of epoch 59 => [0.001]
# Epoch 60/300 - Train Loss: 3.78261975
# Epoch 60/300 - Test Loss: 3.78060127
# lr of epoch 60 => [0.001]
# Epoch 61/300 - Train Loss: 3.78304386
# Epoch 61/300 - Test Loss: 3.77929890
# lr of epoch 61 => [0.001]
# Epoch 62/300 - Train Loss: 3.78492764
# Epoch 62/300 - Test Loss: 3.78333212
# lr of epoch 62 => [0.001]
# Epoch 63/300 - Train Loss: 3.78817144
# Epoch 63/300 - Test Loss: 3.77941918
# lr of epoch 63 => [0.001]
# Epoch 64/300 - Train Loss: 3.77833622
# Epoch 64/300 - Test Loss: 3.77397839
# lr of epoch 64 => [0.001]
# Epoch 65/300 - Train Loss: 3.77761222
# Epoch 65/300 - Test Loss: 3.76817866
# lr of epoch 65 => [0.001]
# Epoch 66/300 - Train Loss: 3.77174952
# Epoch 66/300 - Test Loss: 3.77824280
# lr of epoch 66 => [0.001]
# Epoch 67/300 - Train Loss: 3.77825807
# Epoch 67/300 - Test Loss: 3.76628056
# lr of epoch 67 => [0.001]
# Epoch 68/300 - Train Loss: 3.76897914
# Epoch 68/300 - Test Loss: 3.76479704
# lr of epoch 68 => [0.001]
# Epoch 69/300 - Train Loss: 3.77202295
# Epoch 69/300 - Test Loss: 3.76314679
# lr of epoch 69 => [0.001]
# Epoch 70/300 - Train Loss: 3.76528424
# Epoch 70/300 - Test Loss: 3.76827748
# lr of epoch 70 => [0.001]
# Epoch 71/300 - Train Loss: 3.79870619
# Epoch 71/300 - Test Loss: 3.73702681
# lr of epoch 71 => [0.001]
# Epoch 72/300 - Train Loss: 3.74009736
# Epoch 72/300 - Test Loss: 3.73407098
# lr of epoch 72 => [0.001]
# Epoch 73/300 - Train Loss: 3.73552836
# Epoch 73/300 - Test Loss: 3.73265987
# lr of epoch 73 => [0.001]
# Epoch 74/300 - Train Loss: 3.73255669
# Epoch 74/300 - Test Loss: 3.72607797
# lr of epoch 74 => [0.001]
# Epoch 75/300 - Train Loss: 3.73041929
# Epoch 75/300 - Test Loss: 3.73394944
# lr of epoch 75 => [0.001]
# Epoch 76/300 - Train Loss: 3.74890681
# Epoch 76/300 - Test Loss: 3.70886805
# lr of epoch 76 => [0.001]
# Epoch 77/300 - Train Loss: 3.70043972
# Epoch 77/300 - Test Loss: 3.70024920
# lr of epoch 77 => [0.001]
# Epoch 78/300 - Train Loss: 3.69743100
# Epoch 78/300 - Test Loss: 3.69518632
# lr of epoch 78 => [0.001]
# Epoch 79/300 - Train Loss: 3.69509476
# Epoch 79/300 - Test Loss: 3.69751064
# lr of epoch 79 => [0.001]
# Epoch 80/300 - Train Loss: 3.69506039
# Epoch 80/300 - Test Loss: 3.68557218
# lr of epoch 80 => [0.001]
# Epoch 81/300 - Train Loss: 3.69122005
# Epoch 81/300 - Test Loss: 3.68123507
# lr of epoch 81 => [0.001]
# Epoch 82/300 - Train Loss: 3.68652506
# Epoch 82/300 - Test Loss: 3.68125358
# lr of epoch 82 => [0.001]
# Epoch 83/300 - Train Loss: 3.70083097
# Epoch 83/300 - Test Loss: 3.82622185
# lr of epoch 83 => [0.001]
# Epoch 84/300 - Train Loss: 3.67769581
# Epoch 84/300 - Test Loss: 3.65140836
# lr of epoch 84 => [0.001]
# Epoch 85/300 - Train Loss: 3.65949589
# Epoch 85/300 - Test Loss: 3.64490404
# lr of epoch 85 => [0.001]
# Epoch 86/300 - Train Loss: 3.64172557
# Epoch 86/300 - Test Loss: 3.62655279
# lr of epoch 86 => [0.001]
# Epoch 87/300 - Train Loss: 3.62397319
# Epoch 87/300 - Test Loss: 3.60700833
# lr of epoch 87 => [0.001]
# Epoch 88/300 - Train Loss: 3.61342359
# Epoch 88/300 - Test Loss: 3.59031446
# lr of epoch 88 => [0.001]
# Epoch 89/300 - Train Loss: 3.59341026
# Epoch 89/300 - Test Loss: 3.57806047
# lr of epoch 89 => [0.001]
# Epoch 90/300 - Train Loss: 3.59345453
# Epoch 90/300 - Test Loss: 3.56932882
# lr of epoch 90 => [0.001]
# Epoch 91/300 - Train Loss: 3.58767187
# Epoch 91/300 - Test Loss: 3.56157591
# lr of epoch 91 => [0.001]
# Epoch 92/300 - Train Loss: 3.55069007
# Epoch 92/300 - Test Loss: 3.53202895
# lr of epoch 92 => [0.001]
# Epoch 93/300 - Train Loss: 3.53464999
# Epoch 93/300 - Test Loss: 3.49876044
# lr of epoch 93 => [0.001]
# Epoch 94/300 - Train Loss: 3.46643799
# Epoch 94/300 - Test Loss: 3.50772113
# lr of epoch 94 => [0.001]
# Epoch 95/300 - Train Loss: 3.45249781
# Epoch 95/300 - Test Loss: 3.40525166
# lr of epoch 95 => [0.001]
# Epoch 96/300 - Train Loss: 3.39195644
# Epoch 96/300 - Test Loss: 3.38301992
# lr of epoch 96 => [0.001]
# Epoch 97/300 - Train Loss: 3.37024340
# Epoch 97/300 - Test Loss: 3.33436983
# lr of epoch 97 => [0.001]
# Epoch 98/300 - Train Loss: 3.32925154
# Epoch 98/300 - Test Loss: 3.26215186
# lr of epoch 98 => [0.001]
# Epoch 99/300 - Train Loss: 3.25563765
# Epoch 99/300 - Test Loss: 3.24254476
# lr of epoch 99 => [0.001]
# Epoch 100/300 - Train Loss: 3.19546872
# Epoch 100/300 - Test Loss: 3.19129730
# lr of epoch 100 => [0.001]
# Epoch 101/300 - Train Loss: 3.17222083
# Epoch 101/300 - Test Loss: 3.16763315
# lr of epoch 101 => [0.001]
# Epoch 102/300 - Train Loss: 3.18890878
# Epoch 102/300 - Test Loss: 3.13500322
# lr of epoch 102 => [0.001]
# Epoch 103/300 - Train Loss: 3.05778662
# Epoch 103/300 - Test Loss: 2.71853949
# lr of epoch 103 => [0.001]
# Epoch 104/300 - Train Loss: 2.57996950
# Epoch 104/300 - Test Loss: 2.51469418
# lr of epoch 104 => [0.001]
# Epoch 105/300 - Train Loss: 2.52312951
# Epoch 105/300 - Test Loss: 2.49254440
# lr of epoch 105 => [0.001]
# Epoch 106/300 - Train Loss: 2.54284145
# Epoch 106/300 - Test Loss: 2.59724182
# lr of epoch 106 => [0.001]
# Epoch 107/300 - Train Loss: 3.23674286
# Epoch 107/300 - Test Loss: 2.84503343
# lr of epoch 107 => [0.001]
# Epoch 108/300 - Train Loss: 2.83659761
# Epoch 108/300 - Test Loss: 2.84818559
# lr of epoch 108 => [0.001]
# Epoch 109/300 - Train Loss: 2.83506446
# Epoch 109/300 - Test Loss: 2.85104617
# lr of epoch 109 => [0.001]
# Epoch 110/300 - Train Loss: 2.83571639
# Epoch 110/300 - Test Loss: 2.84373427
# lr of epoch 110 => [0.001]
# Epoch 111/300 - Train Loss: 2.83427480
# Epoch 111/300 - Test Loss: 2.84180095
# lr of epoch 111 => [0.001]
# Epoch 112/300 - Train Loss: 2.83349021
# Epoch 112/300 - Test Loss: 2.84312324
# lr of epoch 112 => [0.001]
# Epoch 113/300 - Train Loss: 2.83377253
# Epoch 113/300 - Test Loss: 2.84360826
# lr of epoch 113 => [0.001]
# Epoch 114/300 - Train Loss: 2.83482256
# Epoch 114/300 - Test Loss: 2.84460391
# lr of epoch 114 => [0.001]
# Epoch 115/300 - Train Loss: 2.83284645
# Epoch 115/300 - Test Loss: 2.84378962
# lr of epoch 115 => [0.001]
# Epoch 116/300 - Train Loss: 2.83231887
# Epoch 116/300 - Test Loss: 2.84419474
# lr of epoch 116 => [0.001]
# Epoch 117/300 - Train Loss: 2.83314249
# Epoch 117/300 - Test Loss: 2.84217626
# lr of epoch 117 => [0.001]
# Epoch 118/300 - Train Loss: 2.83329916
# Epoch 118/300 - Test Loss: 2.84064225
# lr of epoch 118 => [0.001]
# Epoch 119/300 - Train Loss: 2.83252599
# Epoch 119/300 - Test Loss: 2.84041541
# lr of epoch 119 => [0.001]
# Epoch 120/300 - Train Loss: 2.83255027
# Epoch 120/300 - Test Loss: 2.84324185
# lr of epoch 120 => [0.001]
# Epoch 121/300 - Train Loss: 2.83196280
# Epoch 121/300 - Test Loss: 2.84040979
# lr of epoch 121 => [0.001]
# Epoch 122/300 - Train Loss: 2.83201619
# Epoch 122/300 - Test Loss: 2.84172278
# lr of epoch 122 => [0.001]
# Epoch 123/300 - Train Loss: 2.83158343
# Epoch 123/300 - Test Loss: 2.84153174
# lr of epoch 123 => [0.001]
# Epoch 124/300 - Train Loss: 2.83217137
# Epoch 124/300 - Test Loss: 2.84118970
# lr of epoch 124 => [0.001]
# Epoch 125/300 - Train Loss: 2.83117630
# Epoch 125/300 - Test Loss: 2.84275748
# lr of epoch 125 => [0.001]
# Epoch 126/300 - Train Loss: 2.83114592
# Epoch 126/300 - Test Loss: 2.84229195
# lr of epoch 126 => [0.001]
# Epoch 127/300 - Train Loss: 2.83132651
# Epoch 127/300 - Test Loss: 2.84034289
# lr of epoch 127 => [0.001]
# Epoch 128/300 - Train Loss: 2.83086093
# Epoch 128/300 - Test Loss: 2.84221024
# lr of epoch 128 => [0.001]
# Epoch 129/300 - Train Loss: 2.83139166
# Epoch 129/300 - Test Loss: 2.84030954
# lr of epoch 129 => [0.001]
# Epoch 130/300 - Train Loss: 2.83100279
# Epoch 130/300 - Test Loss: 2.84114063
# lr of epoch 130 => [0.001]
# Epoch 131/300 - Train Loss: 2.83118591
# Epoch 131/300 - Test Loss: 2.83916475
# lr of epoch 131 => [0.001]
# Epoch 132/300 - Train Loss: 2.83024985
# Epoch 132/300 - Test Loss: 2.83750834
# lr of epoch 132 => [0.001]
# Epoch 133/300 - Train Loss: 2.82946264
# Epoch 133/300 - Test Loss: 2.83750995
# lr of epoch 133 => [0.001]
# Epoch 134/300 - Train Loss: 2.82802349
# Epoch 134/300 - Test Loss: 2.83763070
# lr of epoch 134 => [0.001]
# Epoch 135/300 - Train Loss: 2.82702321
# Epoch 135/300 - Test Loss: 2.83505130
# lr of epoch 135 => [0.001]
# Epoch 136/300 - Train Loss: 2.82782941
# Epoch 136/300 - Test Loss: 2.83692778
# lr of epoch 136 => [0.001]
# Epoch 137/300 - Train Loss: 2.82873528
# Epoch 137/300 - Test Loss: 2.84181535
# lr of epoch 137 => [0.001]
# Epoch 138/300 - Train Loss: 2.82785749
# Epoch 138/300 - Test Loss: 2.83787550
# lr of epoch 138 => [0.001]
# Epoch 139/300 - Train Loss: 2.82711685
# Epoch 139/300 - Test Loss: 2.83690534
# lr of epoch 139 => [0.001]
# Epoch 140/300 - Train Loss: 2.82700528
# Epoch 140/300 - Test Loss: 2.83627946
# lr of epoch 140 => [0.001]
# Epoch 141/300 - Train Loss: 2.82767692
# Epoch 141/300 - Test Loss: 2.83552592
# lr of epoch 141 => [0.001]
# Epoch 142/300 - Train Loss: 2.82718630
# Epoch 142/300 - Test Loss: 2.83569086
# lr of epoch 142 => [0.001]
# Epoch 143/300 - Train Loss: 2.82785927
# Epoch 143/300 - Test Loss: 2.83818247
# lr of epoch 143 => [0.001]
# Epoch 144/300 - Train Loss: 2.82743164
# Epoch 144/300 - Test Loss: 2.83565133
# lr of epoch 144 => [0.001]
# Epoch 145/300 - Train Loss: 2.82707865
# Epoch 145/300 - Test Loss: 2.84067479
# lr of epoch 145 => [0.001]
# Epoch 146/300 - Train Loss: 2.82723172
# Epoch 146/300 - Test Loss: 2.83618921
# lr of epoch 146 => [0.001]
# Epoch 147/300 - Train Loss: 2.82822658
# Epoch 147/300 - Test Loss: 2.83713030
# lr of epoch 147 => [0.001]
# Epoch 148/300 - Train Loss: 2.82772716
# Epoch 148/300 - Test Loss: 2.83732962
# lr of epoch 148 => [0.001]
# Epoch 149/300 - Train Loss: 2.82712639
# Epoch 149/300 - Test Loss: 2.83806438
# lr of epoch 149 => [0.001]
# Epoch 150/300 - Train Loss: 2.82627129
# Epoch 150/300 - Test Loss: 2.83933772
# lr of epoch 150 => [0.001]
# Epoch 151/300 - Train Loss: 2.82756293
# Epoch 151/300 - Test Loss: 2.83825546
# lr of epoch 151 => [0.001]
# Epoch 152/300 - Train Loss: 2.82790147
# Epoch 152/300 - Test Loss: 2.84019475
# lr of epoch 152 => [0.001]
# Epoch 153/300 - Train Loss: 2.82799835
# Epoch 153/300 - Test Loss: 2.83906626
# lr of epoch 153 => [0.001]
# Epoch 154/300 - Train Loss: 2.82684057
# Epoch 154/300 - Test Loss: 2.83835617
# lr of epoch 154 => [0.001]
# Epoch 155/300 - Train Loss: 2.82718264
# Epoch 155/300 - Test Loss: 2.83611912
# lr of epoch 155 => [0.001]
# Early stopping after 50 epochs of no improvement.
# batch_size: 64   activation_function: ReLU()   learning_rate: 0.001   warmup_iters: 100
# best Epoch :  105  , best_val_loss :  2.49254440344297
#
# Autoencoder training completed in 4.4 mins.

# %%
import matplotlib.pyplot as plt
# Create a plot of the loss curve
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_epoch_loss_list) + 1), train_epoch_loss_list, marker='o', linestyle='-', color='b', label='Training Loss')
# Plot validation loss
plt.plot(range(1, len(test_epoch_loss_list) + 1), test_epoch_loss_list, marker='o', linestyle='-', color='r', label='Validation Loss')
# Mark the best epoch
plt.plot(best_epoch, best_val_loss , marker='o', markersize=8, linestyle='', color='c', label=f'Best Epoch:{best_epoch}')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Pretain AE Loss Curve', fontsize=16)
plt.legend()
plt.grid(True)
plt.ylim(top=8)
plt.show()
